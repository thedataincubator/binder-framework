# %%
import pandas as pd

df = pd.read_csv('Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_-_FY2020.csv')
df
# Out:
#                                  Company Name    company contact  \
# 0                              1 State Street      David Neiburg
# 1                              100 Church LLC  Edward A. Carroll
# 2                        100 Wall Investments       Jerry Branam
# 3                 1-10 Bush Terminal Owner LP     Andrew Kimball
# 4    120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
# ..                                        ...                ...
# 445                         WONTON FOOD, INC.         DONALD LAU
# 446                                Wood Works       Gordon Brawm
# 447           WorldWide Plumbing Supply, Inc.    Surie Lefkowitz
# 448                         WUD Furniture LLC     Keren Springer
# 449                       Wurtec Incorporated          Bill Popp
#
#                  company email company phone                Address  \
# 0       eskoblo@energyspec.com    7186779077          1114 Avenue J
# ...

# %%
# How many different companies are represented in the data set?

# counting the number of diifferent (unique) companies are represented in the data set

df_unique = df['Company Name'].nunique()
df_unique
# Out:
# 439

# %%
df.dtypes
# Out:
# Company Name                                  object
# company contact                               object
# company email                                 object
# company phone                                 object
# Address                                       object
# City                                          object
# State                                         object
# Postcode                                       int64
# Industry                                      object
# Industry descr                                object
# Company Type                                  object
# Current fulltime                             float64
# Job created                                  float64
# Job retain                                   float64
# Effective Date                                object
# Total Savings                                float64
# Savings from beginning receiving benefits    float64
# Borough                                       object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 26 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Company Name                               450 non-null    object
#  1   company contact                            450 non-null    object
#  2   company email                              433 non-null    object
#  3   company phone                              450 non-null    object
#  4   Address                                    450 non-null    object
#  5   City                                       450 non-null    object
#  6   State                                      450 non-null    object
#  7   Postcode                                   450 non-null    int64
#  8   Industry                                   450 non-null    object
#  9   Industry descr                             434 non-null    object
# ...

# %%
df.shape
# Out:
# (450, 26)

# %%
# What is the total number of jobs created for businesses in Queens?

result = df.loc[df["City"]=="Queens",["Job created"]]
result.sum()
# Out:
# Job created    90.0
# dtype: float64

# %%
# How many different unique email domains names are there in the data set?

# nan_values = df['company email'].isna().sum()
# print(nan_values)

# not_nan_values = df['company email'].notna().sum()
# print(not_nan_values)

unique_emails = df['company email'].nunique()
print(unique_emails)
# Out:
# 420

# %%
# Considering only NTAs with at least 5 listed businesses, what is the average total savings and the total jobs created for each NTA?

#df["NTA"]
filtered_df = df[df["NTA"].str.contains('-',na=False)]

#filtered_df['NTA'].str.count('-').sum()

count_strings = filtered_df[filtered_df['NTA'].apply(lambda x: len(x.split('-'))>=4)]
print(count_strings)
# Out:
#                                     Company Name          company contact  \
# 1                                 100 Church LLC        Edward A. Carroll
# 7    141 Lake Avenue Realty c/o JR Produce, Inc.                Josef Raz
# 16                                 55 Water, LLC            Jermy Frenkel
# 17                       72andSunny Partners LLC          Mitchell Gendel
# 46                 American Transit Insurance Co  Edward T McGettigan Jr.
# 54                           Armada New York LLC              Cory Watson
# 84                  Bronx River Media Group, LLC            John Battista
# 96                            Casual Films, Inc.             Barnaby Cook
# 98                              Chase Bank, N.A.          Edward P Rooney
# 119                             D.S. & Durga LLC             Kavita Ahuja
# 129               Deutsche Bank Securities, Inc.   Chandra Gopalakrishnan
# 151                            Evergreen 105 LLC            Michael Berry
# ...
